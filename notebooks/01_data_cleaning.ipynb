# %% [markdown]
# # RetailPulse Phase 1 - Data Cleaning
#
# This notebook loads the raw Excel data, cleans the transactions, engineers features, and saves a processed dataset for downstream analytics.

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().resolve().parent / 'src'))
from pipeline import run_phase_one

# %%
df, path = run_phase_one()
print(df.head())
print('rows', len(df))
print('saved_to', path)

# %%
df.info()

# %%
df.describe(include='all').T
